# %%
from keras.preprocessing import image

# %%
image_path = "./lion.webp"

# %%
img = image.load_img(image_path)
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1600x1056>

# %%
img = img.resize((224, 224))  # Resize to 224x224

# %%
img.size
# Out:
# (224, 224)

# %%
img_arr = image.img_to_array(img)
img_arr.shape
# Out:
# (224, 224, 3)

# %%
import numpy as np

# %%
img_arr = np.expand_dims(img_arr,axis=0)
img_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
img_arr_proc = preprocess_input(img_arr)

model = ResNet50(weights='imagenet')

preds = model.predict(img_arr_proc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
p =  decode_predictions(preds, top=3)
p
# Out:
# [[('n02129165', 'lion', np.float32(0.9822306)),
#   ('n02108551', 'Tibetan_mastiff', np.float32(0.0036210066)),
#   ('n02132136', 'brown_bear', np.float32(0.0020464093))]]

# %%
for i in p[0]: 
    print(i[1],":",round(i[2]*100,2))
# Out:
# lion : 98.22
# Tibetan_mastiff : 0.36
# brown_bear : 0.2

# %%
image_path = "./pizza.webp"

img1 = image.load_img(image_path)
img1_resize = img1.resize((224,224))
img1_arr = image.array_to_img(img1_resize)
img1_arr = np.expand_dims(img1_resize,axis=0)
img1_arr.shape
img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img1_pro = preprocess_input(img1_arr)
y_logist = model.predict(img_pro)
p1 =  decode_predictions(y_logist, top=3)
for i in p1[0]: 
    print(i[1],":",round(i[2]*100,2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# pizza : 67.72
# pomegranate : 21.58
# toilet_seat : 3.82

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=474x316>
